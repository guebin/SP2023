# %% [markdown]
# # 01wk-2: 강의소개
#
# 최규빈
# 2023-03-06
#
# # 수업구성
#
# `1`. 측도론(실변수함수론)
#
# -   확률과정을 이해함에 있어서 필요함.
# -   그런데 학부수준에서는 꼭 필요한 내용은 아님.
# -   대학원 진학 등 깊이 공부 할 학생들은 필요함.
#
# `2`. 확률과정론
#
# -   원래는 금융통계을 위한 백업과목
# -   여러가지 확률과정 중 우리는 마코프체인에만 집중
#
# `3`. 마코프체인의 응용 (유동적으로 변경가능)
#
# -   “마코프체인”이라는 용어가 나오는 응용분야를 리뷰.
# -   MCMC, 베이지안모형, 토픽모형(LDA), 강화학습, 구글페이지랭크 –\> 몇
#     개만 다를 수 있지 않을까?
#
# # 이 수업을 들어야 하는 이유
#
# pass
#
# # 이 수업을 듣지 말아야 하는 이유
#
# `1`. F학점 줄 수 있음.
#
# -   진짜 줌.
#
# `2`. 쓸모가 없다.
#
# -   그동안 제가 강의했던 과목들: R입문, 파이썬입문, 통계전산,
#     데이터시각화, 딥러닝(파이토치/텐서플로우),
# -   측도론: 재미는 있음. 그런데 대학원가서 고급이론을 공부할 것이 아니면
#     쓸모가 없다. (통계학과에서 배우는 가장 이론적인 과목)
# -   확률과정론: 확률과정론 $\to$ 금융공학으로 가는 교과과정은 학부수준에
#     다루기 어려움. 마코프체인은 응용이 많이 되는 편이지만 이론을 꼭
#     알아야 하는건 아니야.
# -   마코프체인의 응용: 꽤 재미있는 토픽들이 많음. 그런데 이 과목에서
#     깊게 다루기 불가능.
#
# `3`. 회귀분석2와 시간이 겹침
#
# -   이영미교수님 수업!
# -   회귀분석2는 엄청 중요한 수업이에요.
# -   지금이라도 늦지 않음
